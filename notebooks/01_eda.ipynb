# %% [markdown]
# # AgriGuard: Uganda Food Prices EDA
#
# ## Objective
# This notebook explores Uganda's food price dataset to uncover:
# - Market price trends across commodities
# - Regional price differences
# - Seasonal fluctuations
# - Volatility in staple foods
# - Data quality issues for downstream ML models
#
# ## Why this matters
# Ugandan farmers and consumers face:
# - Unstable food prices
# - Poor market transparency
# - Limited forecasting tools
#
# AgriGuard uses this data to build:
# - Price prediction models
# - Market intelligence dashboards
# - Farmer decision-support tools

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

plt.style.use("ggplot")
